# %%
import os
from glob import glob
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data_paths = tf.io.matching_files("body_posture_dataset/2/*.jpg")

# %%
path = data_paths[0]

# %%
len(data_paths)
# Out:
# 2676

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
for path in data_paths:
    gfile = tf.io.read_file(path)
    image = tf.io.decode_image(gfile)
    
    inputs = image[tf.newaxis, ...]
    datagen = ImageDataGenerator(
        rotation_range = 20,
        width_shift_range = 0.2,
        height_shift_range = 0.2,
        horizontal_flip = True
    )
    
    result = next(iter(datagen.flow(inputs, save_to_dir="augmentation/2/", save_prefix="aug_2_4", save_format="jpg")))

# %%
#plt.imshow(result[0, :, :, 0])
#plt.show()

# %%
gfile = tf.io.read_file(data_paths[200])
image = tf.io.decode_image(gfile)
plt.imshow(image[:,:,:], "gray")
plt.show()

# %%
image.shape
# Out:
# TensorShape([284, 388, 3])
